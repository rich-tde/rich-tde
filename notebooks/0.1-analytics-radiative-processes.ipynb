# %% [markdown]
# Check under a typical TDE physical parameter, density, temperature, and if needed, electric/magnetic field, what radiation processes are the most prominent.

# %%
import numpy as np
import unyt as u

# %%
Ledd = 1.3*1e42 * u.erg / u.s
R = 1000*u.Rsun

# %%
((Ledd / u.stefan_boltzmann_constant/4/np.pi/R**2)**(1/4)).in_units('K')
# Out:
# unyt_quantity(24781.74602648, 'K')
